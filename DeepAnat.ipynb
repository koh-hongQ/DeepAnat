# %%
# !pip install tensorflow-gpu==2.1.0
# !pip install keras==2.3.1
# Out:
# Requirement already satisfied: tensorflow-gpu==2.1.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (2.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (2.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (3.3.0)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (0.2.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (4.24.4)
# Requirement already satisfied: tensorflow-gpu-estimator<2.2.0,>=2.1.0rc0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (2.1.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.62.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.16.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (0.38.4)
# Requirement already satisfied: scipy==1.4.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.0.8)
# Requirement already satisfied: gast==0.2.2 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorflow-gpu==2.1.0) (1.17.0)
# Requirement already satisfied: h5py in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0) (3.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (65.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (2.31.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (3.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (6.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (3.10)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (4.7.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0) (3.2.2)
# Requirement already satisfied: keras==2.3.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (2.3.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (1.17.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (1.21.6)
# Requirement already satisfied: scipy>=0.14 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: pyyaml in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (6.0.1)
# Requirement already satisfied: h5py in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (3.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\issac\miniconda3\envs\tf21\lib\site-packages (from keras==2.3.1) (1.1.2)

# %%
# %cd drive/MyDrive/DeepAnat/
# !ls
# Out:
# [WinError 3] 지정된 경로를 찾을 수 없습니다: 'drive/MyDrive/DeepAnat/'
# d:\고홍규\2025 한국외대 수학과 3학년 1학기\학부연구생\DeepAnatgit\DeepAnat
# 'ls'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# %% load moduals

import os
import glob
import scipy.io as sio
import numpy as np
import nibabel as nb
import tensorflow as tf
from matplotlib import pyplot as plt

from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import aini_utils as utils
from cnn_models import unet_3d_model

# for compatibility
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
from tensorflow.compat.v1 import GPUOptions

gpu_options = GPUOptions(per_process_gpu_memory_fraction=0.9)
config = ConfigProto(gpu_options=gpu_options)
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33680\1560085833.py in <module>
#       2 device_name = tf.test.gpu_device_name()
#       3 if device_name != '/device:GPU:0':
# ----> 4   raise SystemError('GPU device not found')
#       5 print('Found GPU at: {}'.format(device_name))
#
# SystemError: GPU device not found

# %%
# %% set up path and parameters


dpRoot = os.path.dirname(os.path.abspath('DeepAnat.ipynb'))
os.chdir(dpRoot)
dpData = os.path.join(dpRoot, 'example_data')

block_size = 64
finetune = 1 # 1 for fine-tuning, 0 for training from scratch 

# %% subjects
if finetune :
    subjects = sorted(glob.glob(os.path.join(dpRoot, 'example_data', 'mwu*')))
else :
    subjects = sorted(glob.glob(os.path.join(dpRoot, 'pretrain_data', 'mwu*')))

# %%
# %% load data 
train_block_in = np.array([])
valid_block_in = np.array([])

sz_block = 64    
sz_pad = 1
flip = 1 # flip along x to augment training data
input_list = ['diff_dtiL1', 'diff_dtiL2', 'diff_dtiL3',
              ]

for ii in np.arange(len(subjects)):
    sj = os.path.basename(subjects[ii])
    
    print(sj)
    dpSub = os.path.join(dpData, sj)
    
    fpT1w = os.path.join(dpSub, sj + '_t1w.nii.gz')
    t1w = nb.load(fpT1w).get_data()   
    t1w = np.expand_dims(t1w, -1)

    fpMask = os.path.join(dpSub, sj + '_mask.nii.gz')
    mask = nb.load(fpMask).get_data() 
    mask = np.expand_dims(mask, -1)
        
    input = 0.
    for jj in np.arange(0, len(input_list)):
        
        fpImage = os.path.join(dpSub, sj + '_' + input_list[jj] + '.nii.gz')
        image = nb.load(fpImage).get_data()   
        image = np.expand_dims(image, -1)      
        
        if jj == 0:
            inputs = image
        else:
            inputs = np.concatenate((inputs, image), axis=-1)

    norm_ch = [0, 1, 2]
    t1w_norm, tmp = utils.normalize_image(t1w, t1w, mask)
    inputs_norm, tmp = utils.normalize_image(inputs, inputs, mask, norm_ch)
    
    t1w_norm = t1w_norm * mask # exclude non-brain content from loss calculation
    inputs_norm = inputs_norm * mask
    
    ind_block, ind_brain = utils.block_ind(mask, sz_block=sz_block, sz_pad=sz_pad)
    
    t1w_norm_block = utils.extract_block(t1w_norm, ind_block)
    inputs_norm_block = utils.extract_block(inputs_norm, ind_block)
    mask_block = utils.extract_block(mask, ind_block)
    
    t1w_norm_block = np.concatenate((t1w_norm_block, mask_block), axis=-1)
    
    if flip: # Flip x to augment data
        inputs_norm_block_flip = inputs_norm_block[:,::-1,:,:,:]
        mask_block_flip = mask_block[:,::-1,:,:,:]
        t1w_norm_block_flip = t1w_norm_block[:,::-1,:,:,:]
        
        inputs_norm_block = np.concatenate((inputs_norm_block, inputs_norm_block_flip), axis=0)
        mask_block = np.concatenate((mask_block, mask_block_flip), axis=0)
        t1w_norm_block = np.concatenate((t1w_norm_block, t1w_norm_block_flip), axis=0)
    
    if finetune: # select 20% blocks from each subject for the validation data during fine-tuning
        l = np.shape(mask_block)[0]
        val_num = int(np.round(l * 0.2))
        idx = np.arange(l)
        np.random.shuffle(idx)
        inputs_norm_block = inputs_norm_block[idx,:,:,:,:]
        mask_block = mask_block[idx,:,:,:,:]
        t1w_norm_block = t1w_norm_block[idx,:,:,:,:]
        
        if valid_block_in.size == 0: 
            valid_block_out = t1w_norm_block[0:val_num,:,:,:,:]
            valid_block_in = inputs_norm_block[0:val_num,:,:,:,:]
            valid_block_mask = mask_block[0:val_num,:,:,:,:]    
        else:
            valid_block_out = np.concatenate((valid_block_out, t1w_norm_block[0:val_num,:,:,:,:]), axis=0)
            valid_block_in = np.concatenate((valid_block_in, inputs_norm_block[0:val_num,:,:,:,:]), axis=0)
            valid_block_mask = np.concatenate((valid_block_mask, mask_block[0:val_num,:,:,:,:]), axis=0)


        if train_block_in.size == 0: 
            train_block_out = t1w_norm_block[val_num:l,:,:,:,:]
            train_block_in = inputs_norm_block[val_num:l,:,:,:,:]           
            train_block_mask = mask_block[val_num:l,:,:,:,:]     
        else:
            train_block_out = np.concatenate((train_block_out, t1w_norm_block[val_num:l,:,:,:,:]), axis=0)
            train_block_in = np.concatenate((train_block_in, inputs_norm_block[val_num:l,:,:,:,:]), axis=0)
            train_block_mask = np.concatenate((train_block_mask, mask_block[val_num:l,:,:,:,:]), axis=0)
    
    else: # select 20% subjects as validation data if training from scratch
        if np.mod(ii + 2, 5) == 0: # 1 out of 5 subjects for validation
            print('validation subject')
            
            if valid_block_in.size == 0: 
                valid_block_out = t1w_norm_block
                valid_block_in = inputs_norm_block      
                valid_block_mask = mask_block     
            else:
                valid_block_out = np.concatenate((valid_block_out, t1w_norm_block), axis=0)
                valid_block_in = np.concatenate((valid_block_in, inputs_norm_block), axis=0)
                valid_block_mask = np.concatenate((valid_block_mask, mask_block), axis=0)
        else:
            print('training subject')

            if train_block_in.size == 0: 
                train_block_out = t1w_norm_block
                train_block_in = inputs_norm_block           
                train_block_mask = mask_block     
            else:
                train_block_out = np.concatenate((train_block_out, t1w_norm_block), axis=0)
                train_block_in = np.concatenate((train_block_in, inputs_norm_block), axis=0)
                train_block_mask = np.concatenate((train_block_mask, mask_block), axis=0)
# Out:
# mwu119126
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# mwu120212
# mwu120414

# %%
# %% set up models
# set up models
num_ch = train_block_in.shape[-1]
num_epochs = 30

if finetune: # load pre-trained model
    fnCp = 'unet_all2t1w_hcp'
    fpCp = os.path.join(dpRoot, fnCp, fnCp + '.h5') 
    model_unet = load_model(fpCp, custom_objects={'mean_absolute_error_weighted': utils.mean_absolute_error_weighted})
    print('model loaded:', fnCp)
    adam_opt_unet = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0)
    model_unet.compile(loss = utils.mean_absolute_error_weighted, optimizer = adam_opt_unet)
    model_unet = unet_3d_model(num_ch)
    model_unet.summary()

else: # train from scratch
    adam_opt_unet = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0)
    model_unet.compile(loss = utils.mean_absolute_error_weighted, optimizer = adam_opt_unet)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33680\612216755.py in <module>
#       7     fnCp = 'unet_all2t1w_hcp'
#       8     fpCp = os.path.join(dpRoot, fnCp, fnCp + '.h5')
# ----> 9     model_unet = load_model(fpCp, custom_objects={'mean_absolute_error_weighted': utils.mean_absolute_error_weighted})
#      10     print('model loaded:', fnCp)
#      11     adam_opt_unet = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0)
#
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     581
#     582     if H5Dict.is_supported_type(filepath):
# --> 583         with H5Dict(filepath, mode='r') as h5dict:
#     584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\keras\utils\io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     565                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                                  fs_page_size=fs_page_size)
# --> 567                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     568
#     569             if isinstance(libver, tuple):
#
# c:\Users\issac\miniconda3\envs\tf21\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229         if swmr and swmr_support:
#     230             flags |= h5f.ACC_SWMR_READ
# --> 231         fid = h5f.open(name, flags, fapl=fapl)
#     232     elif mode == 'r+':
#     233         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = 'd:\고홍규\2025 한국외대 수학과 3학년 1학기\학부연구생\DeepAnatgit\DeepAnat\unet_all2t1w_hcp\unet_all2t1w_hcp.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
# train
sz_batch = 1
fnCp = 'unet_MGHfinetuned'
dpCnn = os.path.join(dpRoot, fnCp) 
if not os.path.exists(dpCnn):
    os.mkdir(dpCnn)
    print('create directory')
        
fpCp = os.path.join(dpCnn, fnCp + '.h5')
cp = ModelCheckpoint(fpCp, monitor='val_loss', save_best_only = True)

history = model_unet.fit(x = [train_block_in, train_block_mask], 
                         y = train_block_out, 
                         validation_data = ([valid_block_in, valid_block_mask], valid_block_out),
                         batch_size = sz_batch, 
                         epochs = num_epochs,  
                         shuffle = True, 
                         callbacks = [cp], 
                         verbose = 1)

fpLoss = os.path.join(dpCnn, fnCp + '.mat') 
sio.savemat(fpLoss, {'loss_train':history.history['loss'], 'loss_val':history.history['val_loss']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33680\255212051.py in <module>
#      10 cp = ModelCheckpoint(fpCp, monitor='val_loss', save_best_only = True)
#      11
# ---> 12 history = model_unet.fit(x = [train_block_in, train_block_mask],
#      13                          y = train_block_out,
#      14                          validation_data = ([valid_block_in, valid_block_mask], valid_block_out),
#
# NameError: name 'model_unet' is not defined

# %%
# %% apply 
print('Applying...')

# %% load data
sz_block = 64
sz_pad = 5
sz_crop = 3
input_list = ['diff_meanb0', 'diff_meandwi', 'diff_dtiL1', 'diff_dtiL2', 'diff_dtiL3',
              'diff_dtiDwi1', 'diff_dtiDwi2', 'diff_dtiDwi3', 'diff_dtiDwi4', 'diff_dtiDwi5', 'diff_dtiDwi6']

mse = []

for ii in np.arange(len(subjects)):
    sj = os.path.basename(subjects[ii])
    
    print(sj)
    dpSub = os.path.join(dpData, 'evaluation_subjects', sj)
    
    fpT1w = os.path.join(dpSub, sj + '_t1w.nii.gz')
    t1w = nb.load(fpT1w).get_data()   
    t1w = np.expand_dims(t1w, -1)

    fpMask = os.path.join(dpSub, sj + '_mask.nii.gz')
    mask = nb.load(fpMask).get_data() 
    mask = np.expand_dims(mask, -1)
    
    input = 0.
    for jj in np.arange(0, len(input_list)):
        
        fpImage = os.path.join(dpSub, sj + '_' + input_list[jj] + '.nii.gz')
        image = nb.load(fpImage).get_data()   
        image = np.expand_dims(image, -1)      

        if jj == 0:
            inputs = image
        else:
            inputs = np.concatenate((inputs, image), axis=-1)

    norm_ch = [0, 1, 5, 6, 7, 8, 9, 10] # do not normalize DTI metrics
    t1w_norm, tmp = utils.normalize_image(t1w, t1w, mask)
    inputs_norm, tmp = utils.normalize_image(inputs, inputs, mask, norm_ch) 
    
    ind_block, ind_brain = utils.block_ind(mask, sz_block=sz_block, sz_pad=sz_pad)
    inputs_norm_block = utils.extract_block(inputs_norm, ind_block)
    mask_block = utils.extract_block(mask, ind_block)
    
    t1w_pred_block = np.zeros(mask_block.shape)
    
    for mm in np.arange(0, mask_block.shape[0]):
        tmp = model_unet.predict([inputs_norm_block[mm:mm+1, :, :, :, :], mask_block[mm:mm+1, :, :, :, :]]) 
        t1w_pred_block[mm:mm+1, :, :, :, :] = tmp[:, :, :, :, :-1]

    t1w_pred_vol, tmp = utils.block2brain(t1w_pred_block, ind_block, mask, sz_crop)

    fpPred = os.path.join(dpSub, sj + fnCp + '_predimg_norm.nii.gz')
    utils.save_nii(fpPred, t1w_pred_vol, fpMask)
    
    t1w_mse = (t1w_norm + 3) / 6
    pred_mse = (t1w_pred_vol + 3) / 6
    mse_subject = np.mean((t1w_mse[mask > 0.5] - pred_mse[mask > 0.5]) ** 2)
    print('mean squared error:', mse_subject)
    mse.append(mse_subject)
    
    # transform standardized intensities to normal range
    # can use the mean and std from one of training subjects
    img_mean = np.mean(t1w[mask > 0.5])
    img_std = np.std(t1w[mask > 0.5])
    
    t1w_pred_final = (t1w_pred_vol * img_std + img_mean) * mask
    fpPred = os.path.join(dpSub, sj + fnCp + '_predimg_final.nii.gz')
    utils.save_nii(fpPred, t1w_pred_final, fpMask)

fpMSE = os.path.join(dpCnn, fnCp + '_mse.mat') 
sio.savemat(fpMSE, {'mse':mse})
print('Applying finished')
# Out:
# Applying...
# mwu159744
# evaluation subject
# Applying finished
